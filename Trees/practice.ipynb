# %%
class Node:
    def __init__(self,data,left=None,right=None):
        self.data = data
        self.left = left
        self.right = right

def addNode(self,data):
    pass

# %%
def addNode(self,data):
    if self.data:
        if data < self.data:
            if self.left is None:
                self.left = Node(data)
            else:
                self.left.addNode(data)
        elif data > self.data:
            if self.right is None:
                self.right = Node(data)
            else:
                self.right.addNode(data)
    else:
        self.data = data

# %%
addNode(Node(10),5)

# %%
def addNode(self,data):
    if self.data:
        if data < self.data:
            if self.left is None:
                self.left = Node(data)
            else:
                self.data.addNode(data)
        elif data > self.data:
            if self.right is None:
                self.right = Node(data)
            else:
                self.data.addNode(data)
    else:
        self.data = data
